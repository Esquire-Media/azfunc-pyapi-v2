# %% [markdown]
# # Import the helper functions

# %%
from datetime import datetime
from libs.utils.onspot_oneoff import (
    load_local_settings,
    pull_by_esqids,
    pull_by_address_file,
    get_results_frame,
)

_ = load_local_settings("local.settings.json")

# %% [markdown]
# # Pull by esquids

# %%
id_list = ["EF~35658"]

# %%
result = pull_by_esqids(
    esqids=id_list,
    start=datetime(2026, 1, 1),
    end=datetime(2026, 2, 1),
    pull_type="devices",
    wait=True,
    timeout_seconds=900,
    verbose=True
)
df = get_results_frame(result)
df.head()
# Out:
# {'type': 'FeatureCollection', 'features': [{'id': 'WWMIcyESiXlnPuhwOD9tUyc0t50zzzpJ', 'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': [[[-84.17577403660988, 33.48964977022395], [-84.17597404003406, 33.48952548781261], [-84.175907372226, 33.48946661713404], [-84.17571325125535, 33.48958108786071], [-84.17577403660988, 33.48964977022395]]]}, 'properties': {'name': 'cmjdc2uuc001i7tp5slpijfo5', 'start': '2026-01-01T00:00:00', 'end': '2026-02-01T00:00:00', 'hash': False, 'callback': 'https://webhook.site/.../da570918d0b14f419fb5e66897d2ebfe', 'outputLocation': 'az://esquireonspot.blob.core.windows.net/dashboard/oneoff/042fde71dd6a4f22beb4c7910c85adff/devices?se=2026-04-17T15%3A13%3A57Z&sp=rwl&sv=2023-11-03&sr=c&sig=NeMhwnpmLNx5i7mNLBHkGhmgXII7EHQzt7QaQ7gSZ/A%3D'}}]}
# Polling devices results for ESQID pull...
#   prefix: oneoff/042fde71dd6a4f22beb4c7910c85adff/devices
#   found:  0 / 1
#   found:  0 / 1
#   found:  1 / 1
# Completed.
# ...

# %% [markdown]
# # Pull by addresses

# %% [markdown]
# Requires a csv with the field names
# * address
# * city
# * state
# * zipCode
# * plus4Code

# %%
file_path = "C:/Users/Owner/Downloads/addresses_onspot_test.csv"

# %%
result = pull_by_address_file(
    local_path=file_path,
    pull_type="devices",
    wait=True,
    timeout_seconds=900,
    verbose=True
)
df = get_results_frame(result)
df.head()
# Out:
# {'hash': False, 'name': '3551b75fd1a54e6885bf9735acc20cf2', 'fileName': '658851f5029d41d08abffd138d3bf915.csv', 'fileFormat': {'delimiter': ',', 'quoteEncapsulate': True}, 'mappings': {'street': ['address'], 'city': ['city'], 'state': ['state'], 'zip': ['zipCode'], 'zip4': ['plus4Code']}, 'matchAcceptanceThreshold': 29.9, 'sources': ['az://esquireonspot.blob.core.windows.net/dashboard/oneoff/c4d85728ccb548a1b3126aff272fcea2/inputs/addresses_onspot_test.csv?se=2026-04-17T15%3A29%3A10Z&sp=r&sv=2023-11-03&sr=b&sig=cFGfjFyKDIimXialMZshkg20cRdjL1hFYskxrZiOKcE%3D'], 'outputLocation': 'az://esquireonspot.blob.core.windows.net/dashboard/oneoff/c4d85728ccb548a1b3126aff272fcea2/devices?se=2026-04-17T15%3A29%3A10Z&sp=rwl&sv=2023-11-03&sr=c&sig=2UG9XKIT1rW324Vk661B2yaERe35C0RsvIXY86Klehg%3D', 'callback': 'https://webhook.site/...'}
# Polling devices results for address pull...
#   prefix: oneoff/c4d85728ccb548a1b3126aff272fcea2/devices
#   found:  0 / 1
#   found:  0 / 1
#   found:  1 / 1
# ...

# %% [markdown]
# # Write output

# %%
output_path = "C:/Users/Owner/Downloads/maids.csv"

df[['deviceid']].to_csv(
    output_path, 
    index=False
    )

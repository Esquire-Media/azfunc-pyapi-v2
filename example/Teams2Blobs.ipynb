# %%
import asyncio, json, logging, os, sys

# Load ENVs
os.environ.update(json.load(open("local.settings.json"))["Values"])

# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
logging.getLogger("azure").setLevel(logging.WARNING)

# Define the maximum number of concurrent tasks
MAX_CONCURRENT_TASKS = 128

# Set ProactorEventLoop for Windows to bypass select() limitations
if sys.platform == "win32":
    loop = asyncio.ProactorEventLoop()
    asyncio.set_event_loop(loop)
    MAX_CONCURRENT_TASKS = 60

# Semaphore for limiting concurrency
SEMAPHORE = asyncio.Semaphore(MAX_CONCURRENT_TASKS)

# %%
from typing import Any, Dict
import aiohttp, asyncio, datetime, msal

# Define the number of retries you want to make
MAX_RETRIES = 3

# Define the maximum time you want to wait for a retry
MAX_WAIT_TIME = 15


class MSGraphClient:
    def __init__(self, version: str) -> None:
        """
        Initialize the MSGraphClient with the specified API version.

        Args:
            version (str): The version of the Microsoft Graph API to use.
        """
        self.version = version
        self.access_token = None
        self.expires_at = None
        self.app = msal.ConfidentialClientApplication(
            os.environ["MSGRAPH_CLIENT_ID"],
            authority="https://login.microsoftonline.com/{}".format(
                os.environ["MSGRAPH_TENANT_ID"]
            ),
            client_credential=os.environ["MSGRAPH_CLIENT_SECRET"],
        )

    async def get_access_token(self) -> str:
        """
        Acquire an access token for the Microsoft Graph API.

        Returns:
            str: The access token.

        Raises:
            Exception: If the token cannot be acquired.
        """
        if not self.access_token or self.expires_at <= datetime.datetime.now():
            token_response = self.app.acquire_token_silent(
                ["https://graph.microsoft.com/.default"], account=None
            )
            if not token_response:
                token_response = self.app.acquire_token_for_client(
                    ["https://graph.microsoft.com/.default"]
                )

            if "access_token" not in token_response:
                raise Exception(
                    "Could not acquire token: {}".format(
                        token_response.get("error_description", "Unknown error")
                    )
                )

            self.access_token = token_response["access_token"]
            expires_in = token_response.get("expires_in", 0)
            self.expires_at = datetime.datetime.now() + datetime.timedelta(
                seconds=expires_in
            )

        return self.access_token

    async def make_request(self, path: str, **params: Any) -> Dict[str, Any]:
        """
        Make an authenticated request to the Microsoft Graph API.

        Args:
            path (str): The API endpoint path.
            **params: Additional query parameters.

        Returns:
            dict: The response JSON data.

        Raises:
            Exception: If the request fails after the maximum retries.
        """
        if "https://graph.microsoft.com/" in path:
            url = path
        else:
            url = "https://graph.microsoft.com/{}/{}".format(self.version, path)

        retry_count = 0
        wait_time = 1
        error = None
        while retry_count <= MAX_RETRIES:
            headers = {
                "Authorization": "Bearer " + await self.get_access_token(),
                "Content-Type": "application/json",
            }
            if "filter" in params.keys():
                params["$filter"] = params["filter"]
                del params["filter"]

            async with aiohttp.ClientSession() as session:
                logger.info("REQUESTING | {}".format(url))
                async with session.get(url, headers=headers, params=params) as response:
                    if response.status == 200:
                        error = None
                        return await response.json()
                    elif response.status == 429 or response.status == 503:
                        logger.warning("THROTTLED | {}".format(url))
                        retry_after = int(
                            response.headers.get("Retry-After", wait_time)
                        )
                        wait_time = min(wait_time * 2, MAX_WAIT_TIME)
                        await asyncio.sleep(retry_after)
                        retry_count += 1
                    else:
                        message = "Error making request | {} | {} | {}".format(
                            url, response.status, await response.text()
                        )
                        logger.error(f"RETRYING | {message}")
                        error = Exception(message)
                        wait_time = min(wait_time * 2, MAX_WAIT_TIME)
                        await asyncio.sleep(wait_time)
                        retry_count += 1
        if error:
            raise error
        raise Exception("Maximum retries reached. Unable to make request.")

# %%
class SharePointClient:
    def __init__(self) -> None:
        """
        Initialize the SharePointClient with site URL and tenant information.

        Args:
            site_url (str): The base URL of the SharePoint site.
            tenant_id (str): The tenant ID for authentication.
        """
        self.site_url = "https://esquireadvertising-admin.sharepoint.com"
        self.access_token = None
        self.expires_at = None
        self.app = msal.PublicClientApplication(
            os.environ["MSGRAPH_CLIENT_ID"],
            authority=f"https://login.microsoftonline.com/{os.environ['MSGRAPH_TENANT_ID']}",
            # client_credential=os.environ["MSGRAPH_CLIENT_SECRET"],
        )

    async def get_access_token(self) -> str:
        """
        Acquire an access token for the SharePoint REST API.

        Returns:
            str: The access token.
        """
        if not self.access_token or self.expires_at <= datetime.datetime.now():
            token_response = self.app.acquire_token_silent(
                [f"{self.site_url}/.default"], account=None
            )
            if not token_response:
                token_response = self.app.acquire_token_interactive(
                    scopes=[f"{self.site_url}/.default"]
                )

            if "access_token" not in token_response:
                raise Exception(
                    f"Could not acquire token: {token_response.get('error_description', 'Unknown error')}"
                )

            self.access_token = token_response["access_token"]
            expires_in = token_response.get("expires_in", 0)
            self.expires_at = datetime.datetime.now() + datetime.timedelta(
                seconds=expires_in
            )

        return self.access_token

    async def make_request(self, method: str, path: str, site: str = None, **params: Any) -> Dict[str, Any]:
        """
        Make an authenticated request to the SharePoint REST API.

        Args:
            method (str): HTTP method (GET, POST, etc.).
            path (str): The API endpoint path.
            **params: Additional query parameters or payload.

        Returns:
            dict: The response JSON data.
        """
        url = f"{self.site_url}/{('sites/'+ site + '/') if site else ''}_api/{path}"

        retry_count = 0
        wait_time = 1
        error = None
        while retry_count <= MAX_RETRIES:
            headers = {
                "Authorization": f"Bearer {await self.get_access_token()}",
                "Accept": "application/json",
                "Content-Type": "application/json",
            }

            async with aiohttp.ClientSession() as session:
                logger.info(f"REQUESTING | {method} | {url}")
                async with session.request(method, url, headers=headers, **params) as response:
                    if response.status == 200:
                        error = None
                        return await response.json()
                    elif response.status in [429, 503]:
                        logger.warning(f"THROTTLED | {url}")
                        retry_after = int(response.headers.get("Retry-After", wait_time))
                        wait_time = min(wait_time * 2, MAX_WAIT_TIME)
                        await asyncio.sleep(retry_after)
                        retry_count += 1
                    else:
                        message = f"Error making request | {response.request_info.url} | {response.status} | {await response.text()}"
                        logger.error(f"RETRYING | {message}")
                        error = Exception(message)
                        wait_time = min(wait_time * 2, MAX_WAIT_TIME)
                        await asyncio.sleep(wait_time)
                        retry_count += 1

        if error:
            raise error
        raise Exception("Maximum retries reached. Unable to make request.")

spclient = SharePointClient()

# %%
async def restoreDeletedSite(client: SharePointClient, siteUrl: str):
    await client.make_request(
        "GET", "SPO.Tenant/RestoreDeletedSite", json={"siteUrl": siteUrl}
    )

# %%
from azure.storage.blob.aio import ContainerClient
from azure.core.exceptions import ResourceExistsError
from typing import Any, Dict, List, AsyncGenerator
import asyncio, os


async def get_group_by_team_name(
    client: MSGraphClient, team_name: str
) -> Dict[str, Any]:
    """
    Get a group by its team name.

    Args:
        client (MSGraphClient): The MSGraphClient instance.
        team_name (str): The name of the team.

    Returns:
        dict: The group information.
    """
    try:
        response = await client.make_request(
            "groups",
            filter="resourceProvisioningOptions/Any(x:x eq 'Team') and displayName eq '{}'".format(
                team_name
            ),
        )
        return next(iter(response.get("value", [])), {})
    except Exception as e:
        logger.error(f"Failed to get group by team name: {e}")
        return {}


async def get_channels_for_group(
    client: MSGraphClient, group_id: str
) -> List[Dict[str, Any]]:
    """
    Get the channels for a specified group.

    Args:
        client (MSGraphClient): The MSGraphClient instance.
        group_id (str): The group ID.

    Returns:
        list: A list of channels.
    """
    try:
        response = await client.make_request(f"teams/{group_id}/channels")
        return response.get("value", [])
    except Exception as e:
        logger.error(f"Failed to get channels for group {group_id}: {e}")
        return []


async def get_drive_for_channel(
    client: MSGraphClient, group_id: str, channel_id: str
) -> Dict[str, Any]:
    """
    Get the drive associated with a channel.

    Args:
        client (MSGraphClient): The MSGraphClient instance.
        group_id (str): The group ID.
        channel_id (str): The channel ID.

    Returns:
        dict: The drive information.
    """
    try:
        return await client.make_request(
            f"teams/{group_id}/channels/{channel_id}/filesFolder"
        )
    except Exception as e:
        logger.error(f"Failed to get drive for channel {channel_id}: {e}")
        return {}


async def get_all_files_in_drive(
    client: MSGraphClient, drive_id: str, folder_id: str
) -> AsyncGenerator[Dict[str, Any], None]:
    """
    Get all files in a drive folder, recursively.

    Args:
        client (MSGraphClient): The MSGraphClient instance.
        drive_id (str): The drive ID.
        folder_id (str): The folder ID.

    Yields:
        dict: Information about each file.
    """
    select = "id,name,folder,file,size,@microsoft.graph.downloadUrl,parentReference"
    items = await client.make_request(
        "drives/{}/items/{}/children".format(drive_id, folder_id), select=select
    )

    while True:
        for item in items.get("value", []):
            if item.get("file"):
                yield item

            elif item.get("folder"):
                async for sub_item in get_all_files_in_drive(
                    client, drive_id, item["id"]
                ):
                    yield sub_item

        if "@odata.nextLink" in items:
            items = await client.make_request(items["@odata.nextLink"], select=select)
        else:
            break


async def process_file(
    container_client: ContainerClient, team_name: str, file: Dict[str, Any]
) -> None:
    """
    Process and upload a file to Azure Blob Storage.

    Args:
        container_client (ContainerClient): The Azure Blob Storage container client.
        team_name (str): The name of the team.
        file (dict): The file information.
    """
    async with SEMAPHORE:
        try:
            blob = container_client.get_blob_client(
                "{}/{}/{}".format(
                    team_name,
                    file["parentReference"]["path"].split(":/")[-1],
                    file["name"],
                )
            )

            if not await blob.exists():
                logger.info(f"STARTING {blob.blob_name}")
                await blob.start_copy_from_url(file["@microsoft.graph.downloadUrl"])
            else:
                blob_props = await blob.get_blob_properties()
                if file.get("size") != blob_props.get("size"):
                    if blob_props.copy.status != "pending":
                        logger.warning(f"RESTARTING {blob.blob_name}")
                        await blob.delete_blob()
                        await blob.start_copy_from_url(
                            file["@microsoft.graph.downloadUrl"]
                        )
                    else:
                        logger.info(f"TRANSFERING {blob.blob_name}")
        except ResourceExistsError:
            logger.warning(f"Blob {blob.blob_name} already exists.")
        except Exception as e:
            logger.error(f"Error processing file {file['name']}: {e}")


async def export_conversation_history(
    client: MSGraphClient,
    container_client: ContainerClient,
    group: dict,
    channel: dict,
    team_name: str,
) -> None:
    """
    Export the entire conversation history for a given channel and save it to a blob in JSON format.

    Args:
        client (MSGraphClient): The MSGraphClient instance.
        container_client (ContainerClient): The Azure Blob Storage container client.
        group_id (str): The group ID.
        channel_id (str): The channel ID.
        team_name (str): The name of the team.
    """
    try:
        messages = []
        url = "teams/{}/channels/{}/messages".format(group["id"], channel["id"])
        while url:
            response = await client.make_request(url)
            messages.extend(response.get("value", []))
            url = response.get("@odata.nextLink", None)

        blob = container_client.get_blob_client(
            "{}/{}_conversation_history.json".format(team_name, channel["displayName"])
        )
        if not await blob.exists():
            await blob.upload_blob(json.dumps(messages))
            logger.info(
                "Exported conversation history for channel {} in team {}.".format(
                    channel["displayName"], team_name
                )
            )
    except Exception as e:
        logger.error(
            "Failed to export conversation history for channel {} in team {}: {}".format(
                channel["displayName"], team_name, e
            )
        )


async def process_channel(
    client: MSGraphClient,
    container_client: ContainerClient,
    group: Dict[str, Any],
    team_name: str,
    channel: Dict[str, Any],
) -> None:
    """
    Process a channel by retrieving its drive and files, then uploading them to Azure Blob Storage.

    Args:
        client (MSGraphClient): The MSGraphClient instance.
        container_client (ContainerClient): The Azure Blob Storage container client.
        group (dict): The group information.
        team_name (str): The name of the team.
        channel (dict): The channel information.
    """
    async with SEMAPHORE:
        logger.info(
            "STARTING | Team: {} | Channel: {}".format(
                group["displayName"], channel["displayName"]
            )
        )
        drive = await get_drive_for_channel(client, group["id"], channel["id"])

        if drive:
            async for file in get_all_files_in_drive(
                client, drive["parentReference"]["driveId"], drive["id"]
            ):
                await process_file(container_client, team_name, file)
            await export_conversation_history(
                client, container_client, group, channel, team_name
            )
        logger.info(
            "FINISHED | Team: {} | Channel: {}".format(
                group["displayName"], channel["displayName"]
            )
        )


async def process_team(
    client: MSGraphClient, container_client: ContainerClient, team_name: str
) -> None:
    """
    Process a team by retrieving its group, channels, and files, then uploading them to Azure Blob Storage.

    Args:
        client (MSGraphClient): The MSGraphClient instance.
        container_client (ContainerClient): The Azure Blob Storage container client.
        team_name (str): The name of the team.
    """
    async with SEMAPHORE:
        group = await get_group_by_team_name(client, team_name)
        if group:
            logger.info("STARTING | Team: {}".format(group["displayName"]))
            channels = await get_channels_for_group(client, group["id"])
            channel_tasks = [
                process_channel(client, container_client, group, team_name, channel)
                for channel in channels
            ]
            await asyncio.gather(*channel_tasks)
            logger.info("FINISHED | Team: {}".format(group["displayName"]))


async def process_site(
    client: MSGraphClient,
    container_client: ContainerClient,
    team_name: str,
    channel_name: str,
    site_id: str,
):
    async with SEMAPHORE:
        logger.info("STARTING | Team: {} | Channel: {}".format(team_name, channel_name))
        drive = await client.make_request(f"sites/{site_id}/drive")
        folder = next(
            (
                obj
                for obj in (
                    await client.make_request(f"drives/{drive['id']}/root/children")
                )["value"]
                if obj["name"] == channel_name
            )
        )

        if drive and folder:
            async for file in get_all_files_in_drive(client, drive["id"], folder["id"]):
                await process_file(container_client, team_name, file)
        logger.info(
            "FINISHED | Team: {} | Channel: {}".format(team_name, channel_name)
        )


async def get_all_sites(client: MSGraphClient) -> List[Dict[str, Any]]:
    """Retrieve all SharePoint sites."""
    logger.info("Fetching active SharePoint sites...")
    sites = []
    url = "sites?search=*"

    while url:
        response = await client.make_request(url)
        sites.extend(response.get("value", []))
        url = response.get("@odata.nextLink")

    return sites


async def get_deleted_sites(client: MSGraphClient) -> List[Dict[str, Any]]:
    """Retrieve all deleted SharePoint sites."""
    logger.info("Fetching deleted SharePoint sites...")
    deleted_sites = []
    response = await client.make_request(
        "sites/esquireadvertising-admin.sharepoint.com/lists"
    )
    for item in response["value"]:
        if item["name"] == "DO_NOT_DELETE_SPLIST_TENANTADMIN_ALL_SITES_AGGREGA":
            list_id = item["id"]
            break

    url = f"sites/esquireadvertising-admin.sharepoint.com/lists/{list_id}/items?$expand=fields"
    while url:
        response = await client.make_request(url)
        deleted_sites.extend(response.get("value", []))
        url = response.get("@odata.nextLink")

    return deleted_sites

# %%
# Instantiate the MSGraphClient class
client = MSGraphClient("v1.0")

# %%
import pandas as pd
active_sites = pd.DataFrame(await get_all_sites(client))
deleted_sites = await get_deleted_sites(client)

# %%
active_sites[active_sites["name"].str.startswith("Sas")][["name","id"]].to_dict(orient="records")

# %%
container_client = ContainerClient.from_connection_string(
    os.environ["COLD_STORAGE"], "teams"
)
await process_site(client, container_client, "Saslow & Henebry's Jewelry Stores", "General", "esquireadvertising.sharepoint.com,1ac95474-82c2-4103-93af-df8020782b24,41703526-6ffd-4d8a-82d1-a9f8412117fc")
await process_site(client, container_client, "Saslow & Henebry's Jewelry Stores", "PM", "esquireadvertising.sharepoint.com,e4c29f81-ffca-43f4-ae06-4e14cbd8dd9d,0f97ccc1-0b45-463c-aa1b-2677193a7448")
await process_site(client, container_client, "Saslow & Henebry's Jewelry Stores", "Creative", "esquireadvertising.sharepoint.com,cc1c1e31-5497-4a39-9363-4be874cdc854,0f97ccc1-0b45-463c-aa1b-2677193a7448")
await process_site(client, container_client, "Saslow & Henebry's Jewelry Stores", "AdOps", "esquireadvertising.sharepoint.com,ffdd0805-ff81-4f48-a18a-b1b84cd684b8,0f97ccc1-0b45-463c-aa1b-2677193a7448")
# Out:
# INFO:__main__:STARTING | Team: Saslow & Henebry's Jewelry Stores | Channel: General
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/sites/esquireadvertising.sharepoint.com,1ac95474-82c2-4103-93af-df8020782b24,41703526-6ffd-4d8a-82d1-a9f8412117fc/drive
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!dFTJGsKCA0GTr9-AIHgrJCY1cEH9b4pNgtGp-EEhF_ygDjCLNRRSTYO942gzLE4t/root/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!dFTJGsKCA0GTr9-AIHgrJCY1cEH9b4pNgtGp-EEhF_ygDjCLNRRSTYO942gzLE4t/items/01P7E2LHZFJHV6OD3LNJA356YE53D5R4HU/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/General/ESQ_Creative Sale & Promotion Outline - Saslow & Henebry.xlsx
# INFO:__main__:FINISHED | Team: Saslow & Henebry's Jewelry Stores | Channel: General
# INFO:__main__:STARTING | Team: Saslow & Henebry's Jewelry Stores | Channel: PM
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/sites/esquireadvertising.sharepoint.com,e4c29f81-ffca-43f4-ae06-4e14cbd8dd9d,0f97ccc1-0b45-463c-aa1b-2677193a7448/drive
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!gZ_C5Mr_9EOuBk4Uy9jdncHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/root/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!gZ_C5Mr_9EOuBk4Uy9jdncHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/012TUOTVRYVB42H4SQONFYVBZEANMYC6YH/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!gZ_C5Mr_9EOuBk4Uy9jdncHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/012TUOTVURMLFEXWOFP5GLOF2577OHJDTC/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!gZ_C5Mr_9EOuBk4Uy9jdncHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/012TUOTVV6AYSVWFHYR5FIHPXNBLUVCI7Q/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/PM/Documents/Past IO/Saslow&Henebry'sJewelry_InsertionOrder_04142023 - Sheet1_encrypted_.pdf
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/PM/Documents/Past IO/Saslow&Henebry'sJewelry_InsertionOrder_07252023 - Sheet1 - signed.pdf
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/PM/Documents/Past IO/Saslow&Henebry'sJewelry_InsertionOrder_101223 - signed.pdf
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/PM/Documents/Past IO/Saslow&Henebry'sJewelry_InsertionOrder_101223.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/PM/Documents/Past IO/Saslow&Henebry'sJewelry_InsertionOrder_12282023.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/PM/Documents/ESQ_MutualNDA_Saslow&HenebrysJewelry - signed.pdf
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/PM/Documents/Esquire Advertising-Saslows & Henebrys Sales Data Analysis.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/PM/Documents/Saslow&Henebry'sJewelry_InsertionOrder_12282023 - signed.pdf
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/PM/Documents/Saslows October Competitor Analysis.xlsx
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!gZ_C5Mr_9EOuBk4Uy9jdncHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/012TUOTVTZU3I2ELT4EJAJEIQPVJKQKFKP/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!gZ_C5Mr_9EOuBk4Uy9jdncHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/012TUOTVSPOJ6WMLO2DNGJTAGSI7SIMJQG/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!gZ_C5Mr_9EOuBk4Uy9jdncHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/012TUOTVUI7ATX22XC2VEIVKJSMAIELQC3/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!gZ_C5Mr_9EOuBk4Uy9jdncHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/012TUOTVTW32BAOHMFQZD2KH6VOIMJAHKS/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/PM/Presentations/SetUp/Audiences/Competitors/Saslows & Henebrys-competitors Targets.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/PM/Presentations/Copy of Store Locations - Saslow.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/PM/Screenshot 2023-05-01 at 1.51.08 PM.png
# INFO:__main__:FINISHED | Team: Saslow & Henebry's Jewelry Stores | Channel: PM
# INFO:__main__:STARTING | Team: Saslow & Henebry's Jewelry Stores | Channel: Creative
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/sites/esquireadvertising.sharepoint.com,cc1c1e31-5497-4a39-9363-4be874cdc854,0f97ccc1-0b45-463c-aa1b-2677193a7448/drive
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/root/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UFVST3YD5JVQRFYVSGLLYPAVFDI/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UAPOAKDAIYJ5BFJMQYF7DVZCXWW/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UBJSDIBY36JXBGI74MJSL57WQEV/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UBPEFZUOVPE5RBIZH7AOVVNPR6I/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UH6QKZRBGTUGBHISKZC2OWHKOB2/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UAUEEALJKIJ2JAIYGVS6Y54RJXL/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UB5KL2VX4OB45C2353MO6OL2XBS/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/EVG/01/Saslow-EVGS-01-300x600.gif
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/EVG/01/Saslow-EVGS-01-300x600.psd
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UE3KKNQGO5XTVEZ5IXGUGYEQM2J/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/EVG/02/Saslow-EVG-02-300x600.gif
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/EVG/02/Saslow-EVG-02-300x600.psd
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UA5CDQ5AZ7IJVCIYWIPX5SHAV32/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UCGIFVBREMHMZFLJYM74WYUYH5U/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/4JKL/63763.jpg
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/4JKL/martini_studs_wg.jpg
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/4JKL/yg_4prong_studs.jpg
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UG55M6UQXU65RBKAI7P42VOBGQK/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/Logo/saslows-and-henbrys-sparkle-tagline-black.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/Logo/SaslowsHenebrys-BrandGuidelines-22.pdf
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/Logo/White South Sparkles.png
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UCP45GSQ2OLTVAIYXTFKHV25XZK/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/Shutterstock Backgrounds/pexels-zaksheuskaya-1568607.jpg
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/Shutterstock Backgrounds/shutterstock_1024527772 [Converted].png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/Shutterstock Backgrounds/shutterstock_1024527772.eps
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/Shutterstock Backgrounds/shutterstock_1144513490.jpg
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/Shutterstock Backgrounds/shutterstock_1241972050.eps
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/Shutterstock Backgrounds/shutterstock_1915554283.eps
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/Shutterstock Backgrounds/shutterstock_2113394117.jpg
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/Shutterstock Backgrounds/shutterstock_2244450677.jpg
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/Shutterstock Backgrounds/shutterstock_443850274 (2).eps
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/13A.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/13B.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/13G.jpg
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/13I.jpg
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/18D.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/18G.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/3A.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/3D.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/4B.JPG
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/4D.jpg
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/4H.jpg
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/4H.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/6K.JPG
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/6L.JPG
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/6N.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/9D (2).png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/9D.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/D03060.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/images to ESQ/Mood Board.pdf
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UAZBH2PRB3HXBBLIW5EUW3LRIBK/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UCZ2JGWK4TYAFAYVADY46ZZ3GCQ/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Mother's Day/01/120x600.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Mother's Day/01/160x600.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Mother's Day/01/300x250.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Mother's Day/01/300x50.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Mother's Day/01/320x50.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Mother's Day/01/468x60.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Mother's Day/01/728x90.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Mother's Day/01/Mother'sDay02~300x600.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Mother's Day/01/Mother'sDay02Social~.psd
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UAQMLEMX5WJWFBJGMN6ZZQAGQ3O/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Mother's Day/02/120x600.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Mother's Day/02/160x600.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Mother's Day/02/300x250.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Mother's Day/02/300x50.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Mother's Day/02/320x50.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Mother's Day/02/468x60.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Mother's Day/02/728x90.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Mother's Day/02/Mother'sDay04~300x600.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Mother's Day/02/Mother'sDay04Social~.psd
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UBA676DGYTFUJF3VC4NOQHRZSD6/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UGS7OSW2SLSSBGIANAHWX23OHHM/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Proofs/Graduation EVGs/Saslow0EVG-03-300x600.gif
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Proofs/Graduation EVGs/Saslow0EVG-03-300x600.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Proofs/Graduation EVGs/Saslow-EVG-02-300x600.gif
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Proofs/Graduation EVGs/Saslow-EVG-02-300x600.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Proofs/Graduation EVGs/Saslow-EVG-04-300x600.gif
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Proofs/Graduation EVGs/Saslow-EVG-04-300x600.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Proofs/Graduation EVGs/Saslow-EVGS-01-300x600.gif
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Proofs/Graduation EVGs/Saslow-EVGS-01-300x600.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Proofs/Mother'sDay01~300x600.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2023/05 May 2023/Proofs/Mother'sDay03~300x600.psd
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UCZAXMP7TKV3NF3OY476DRDG66Q/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UHMLCQ45P4FCRFLCQ3ZOGSCW25D/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UCQW45JANWKV5D22VWV5WQ625VA/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2024/OTT Videos/Saslow Valentine's Day Wrapper/Custom Design 4-Revised-2.mp4
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2024/OTT Videos/Saslow Valentine's Day Wrapper/Custom Design-2-Revised-2.mp4
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2024/OTT Videos/Saslow Valentine's Day Wrapper/Saslow-EVG-02-300x600.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2024/OTT Videos/Saslow Valentine's Day Wrapper/Saslow's&Henebry'sJewelers_ALL_CUST_STORE_CUST_NA_OTTWrapper~ValentinesDay24.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2024/OTT Videos/Saslow Valentine's Day Wrapper/Saslow's&Henebry'sJewelers_ALL_CUST_STORE_CUST_NA_OTTWrapper~ValentinesDay24V1.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2024/OTT Videos/Saslow Valentine's Day Wrapper/Saslow's&Henebry'sJewelers_ALL_CUST_STORE_CUST_NA_OTTWrapper~ValentinesDay24V1.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2024/OTT Videos/Saslow Valentine's Day Wrapper/Saslow's&Henebry'sJewelers_ALL_CUST_STORE_CUST_NA_OTTWrapper~ValentinesDay24V2.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2024/OTT Videos/Saslow Valentine's Day Wrapper/Saslow's&Henebry'sJewelers_ALL_CUST_STORE_CUST_NA_OTTWrapper~ValentinesDay24V2.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2024/OTT Videos/Saslow Valentine's Day Wrapper/Screenshot 2024-01-25 at 2.07.15 PM.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2024/OTT Videos/Saslow Valentine's Day Wrapper/shutterstock_2366546153.jpg
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2024/OTT Videos/Custom Design 4-Revised-2.mp4
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Display/2024/OTT Videos/Custom Design-2-Revised-2.mp4
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UHKFMTEPTQX5BA2KTRL7DOKGWOD/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UFOOQXOV7KIHND2VLG5MOKHDZCI/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UFVXIOI27N26BBIPB6ECLIRY4NN/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UEAFCFVHBPF2ZFLHEBX36KFEUSS/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/01/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MilestonesEVG.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/01/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MilestonesEVG01.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/01/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MilestonesEVG02.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/01/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MilestonesEVG03.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/01/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MilestonesEVG04.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/01/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MilestonesEVG05.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/01/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MilestonesEVG06.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/01/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MilestonesEVG07.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/01/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MilestonesEVG08.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/01/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MilestonesEVG09.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/01/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Video~MilestonesEVG.mp4
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!MR4czJdUOUqTY0vodM3IVMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01W6IP5UDXFHO4O2SDK5ELWNVTDWSVHFPW/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/02/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MomentEVG.psd
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/02/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MomentEVG01.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/02/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MomentEVG02.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/02/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MomentEVG03.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/02/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MomentEVG04.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/02/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MomentEVG05.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/02/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MomentEVG06.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/02/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MomentEVG07.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/02/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MomentEVG08.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/02/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Carousel~MomentEVG09.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Social/EVG/05 May/02/Saslow's&Henebry'sJewelers_ALL_EVG_MISC_NA_NA_Video~MomentEVG.mp4
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Saslow's&Henebry'sJewelers_ALL_CUST_STORE_CUST_NA_OTTWrapper~ValentinesDay24V1.png
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/Creative/Saslow's&Henebry'sJewelers_ALL_CUST_STORE_CUST_NA_OTTWrapper~ValentinesDay24V2.png
# INFO:__main__:FINISHED | Team: Saslow & Henebry's Jewelry Stores | Channel: Creative
# INFO:__main__:STARTING | Team: Saslow & Henebry's Jewelry Stores | Channel: AdOps
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/sites/esquireadvertising.sharepoint.com,ffdd0805-ff81-4f48-a18a-b1b84cd684b8,0f97ccc1-0b45-463c-aa1b-2677193a7448/drive
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/root/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R3S7DOEXB4XRBGKNMNGOECC4FYP/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R7NQHAFUCOE4VFZRYHZZVTQ5CC4/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZRJEKPRDA5LBCLOUD35JDH7F3W/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R73UKZOX6XBDZF2B4TTZRT4JI7J/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_05/Final/Saslow & Henebry''s Jewelry Stores_Standard_2023_05_audit.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_05/Final/Saslow__Henebrys_Jewelry_Stores_Standard_2023_05.xlsx
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R72QZ4ZQGOVS5HZ5GEPCYJJR4QW/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_05/Sales/Customer Sales May-NEW-UPDATED.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_05/Sales/Saslows NewCustSalesMay.CSV
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R7UJ5NXMRMO3FAIQZ3J4YR7PHMI/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RY3HF6DVIQYBZBJTUOUOJVZ3PJ7/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_05/Targets/Competitors/Saslow&Henebrys_VR_report_2023-05-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R5S5X3Y4Z4G45DY6DHEQCP5SQLR/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RYIOH4FAOAEBZCY4XRTZVZKPE33/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_06/Final/Saslow & Henebry''s Jewelry Stores_Standard_2023_06_audit.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_06/Final/Saslow__Henebrys_Jewelry_Stores_Standard_2023_06.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_06/Final/TESTING_Saslow__Henebrys_Jewelry_Stores_Standard_2023_06.xlsx
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R3LCWZAVB5F75CKN5SSINFBGEQM/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_06/Sales/Customers June 2023 Dont Use.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_06/Sales/Customers June 2023-2.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_06/Sales/Customers June-NEW-UPDATED.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_06/Sales/New Customers June 2023.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZ73UO7DNWKQFFLJ37Q37EML7NB/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R74TWYNACDQVRHZOSMYIXL6K2CZ/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R25YZXZU2WHF5G2A7WG3NSVOMLR/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_06/Targets/Competitors/Saslow&Henebrys_VR_report/Saslow&Henebrys_VR_report_2023-06-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R4Y2HRHC26TPJE3G6JEWKTJF3RX/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R7KFVKD7PRDLVF2RTGAXDLQUU67/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_07/Final/Saslow & Henebry''s Jewelry Stores_Standard_2023_07_audit.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_07/Final/Saslow__Henebrys_Jewelry_Stores_Standard_2023_07.xlsx
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R65YSPSUM5TAZD2ANJYCPKFPV3B/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_07/Sales/JulySALES Saslows.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_07/Sales/JulySALES Saslows.xlsx
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZA3SBLRFIH7ZFI6NJQN45FSQLG/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZFOQ7GQNPKURFL2TTLTOGAKHQI/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_07/Targets/Competitors/Saslow&Henebrys_VR_report_2023-07-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R27ZIM322SR4ZAIFFUDQJMBVF7P/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R52VAR2NNJGNVBK3J5LVYDZNCXC/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_07/Targets/Competitors_StoreLocations/Saslow&Henebrys_Custom_VR_StoreLocations_report/Saslow&Henebrys_Custom_VR_StoreLocations_report_2023-07-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R7MT3QQY4BWTVGYAMKNLMEXCQKS/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_07/Targets/Custom Demographic/SaslowandHenebrys-CD-0723-DEMOGRAPHICS-1690377137030.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZNUUGPUH5L6ZHZJLNAZPPURLJD/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZGHHABW3ULWJDYZ7W4F6RW3HDJ/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_08/Final/Saslow & Henebry''s Jewelry Stores_Standard_2023_08_audit.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_08/Final/Saslow__Henebrys_Jewelry_Stores_Standard_2023_08.xlsx
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RY5BEZYCWMA3NCZQNVQSB6QT7L3/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_08/Sales/AugustSales.CSV
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R2K2CYJPHYWURCLLF7CFJ7I22OK/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RYCUUAHFJIWF5H2PQ37J4LDGDAU/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_08/Targets/Competitors/Saslow&Henebrys_VR_report_2023-08-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R6IMSFNVKDFFRBZIRJOUFC53SW2/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_08/Targets/Custom Audience/Saslow&Henebrys_Custom_VR_StoreLocations_report_2023-08-28.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_08/Targets/Custom Audience/SaslowandHenebrys-CD-0823-DEMOGRAPHICS-1692109653591.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_08/Targets/Custom Audience/SaslowsHenebrys_AnniversarysCustomAudience_0823.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_08/Targets/Custom Audience/SaslowsHenebrys_BirthdaysCustomAudience_0823.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R3LHSZLJWBE7NH3AZJRK46R3A37/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R4FMO24TZZBTNFL6GM6HR5Z24UZ/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_09/Final/Saslow & Henebry''s Jewelry Stores_Standard_2023_09_audit.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_09/Final/Saslow__Henebrys_Jewelry_Stores_Standard_2023_09.xlsx
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R5WAPL4SB4R7FDYDDTMDATONJJC/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_09/Sales/SeptemberSales.CSV
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R26QNKFSG5FVNEIAWCDVL3BMHBJ/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RYE5KJAWZGT3JAKLZTYRKGJLU4S/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R3Z7EOHI7E5YZAJG7FUWQMBM5ZG/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_09/Targets/Competitors/Saslow&Henebrys_VR_report/Saslow&Henebrys_VR_report_2023-09-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R4SKKU2YXBMPJEY4WBMHMEY5KET/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R7UIQWJARMT2BAKQAO4ICRII4VE/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_09/Targets/Custom Audience/Saslow&Henebrys_Custom_VR_StoreLocations_report/Saslow&Henebrys_Custom_VR_StoreLocations_report_2023-09-28.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_09/Targets/Custom Audience/SaslowandHenebrys-CD-0923-DEMOGRAPHICS.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_09/Targets/Custom Audience/SaslowsHenebrys_ChristiansburgAnniversarys_0923.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_09/Targets/Custom Audience/SaslowsHenebrys_ChristiansburgBirthdays_0923.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_09/Targets/Custom Audience/SaslowsHenebrys_FayettevilleAnniversarys_0923.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_09/Targets/Custom Audience/SaslowsHenebrys_FayettevilleBirthdays_0923.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_09/Targets/Custom Audience/SaslowsHenebrys_HickoryAnniversarys_0923.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_09/Targets/Custom Audience/SaslowsHenebrys_HickoryBirthdays_0923.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R7L2UL4V7CJRZGY7F62D4TBXQD4/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZL7Q42327IANHZ7UJ4ZMNOLH24/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_10/Final/Saslow & Henebry''s Jewelry Stores_Standard_2023_10_audit.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_10/Final/Saslow__Henebrys_Jewelry_Stores_Standard_2023_10.xlsx
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R2PILJ4I7XTNVBY5GBZNL76RNW5/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_10/Sales/OctoberSales.CSV
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZGODSX7YWXTZBK56NFFJDNM3F4/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R4OWFUPENB7ZZC3PH3FF5TF5LKL/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R7RWXAKYLELJRCJGBG6YK7WRY7H/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_10/Targets/Competitors/Saslow&Henebrys_VR_report/Saslow&Henebrys_VR_report_2023-10-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R5WRJ4FNI4ANJE3XXZD7BGJJOHR/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R6J7NYO45HCGRDZIH5DXJJGO7CC/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_10/Targets/Custom Audience/Saslow&Henebrys_Custom_VR_StoreLocations_report/Saslow&Henebrys_Custom_VR_StoreLocations_report_2023-10-28.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_10/Targets/Custom Audience/SaslowandHenebrys-CD-1023-DEMOGRAPHICS-1697057691636.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_10/Targets/Custom Audience/SaslowsHenebrys_Anniversaries_1023.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_10/Targets/Custom Audience/SaslowsHenebrys_Birthdays_1023.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RYGGBHBZWJXG5CLG4IR4TJYXURT/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RYPRUAHZLYR7VD3AZAE33QRWYJI/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_11/Final/Saslow & Henebry''s Jewelry Stores_Standard_2023_11_audit.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_11/Final/Saslow__Henebrys_Jewelry_Stores_Standard_2023_11.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_11/Final/Saslow__Henebrys_Jewelry_Stores_Standard_2023_NOV.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_11/Final/Saslows December Competitor Analysis.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_11/Final/Saslows New - Repeat Customers (November).xlsx
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R5T4QFANJS4FVCZ3IP2C2Z6PFML/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_11/Sales/NovemberSales.CSV
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZJR4GEGR5XLRDIQXTP32T2V2C6/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R6EW5BAZKMOXRFLGCKVVNJXC5AS/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R7TS5N7XFOCD5HJUWZNUWUYLF7W/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_11/Targets/Competitors/Saslow&Henebrys_VR_report/Saslow&Henebrys_VR_report_2023-11-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R6IVODH7BIJABAYQK6AJ54SROMU/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R2CE6L7SUQPWRHZXPSIT7NNUY5G/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_11/Targets/Competitors - OTT/Saslow&Henebrys_VR_report/Saslow&Henebrys_VR_report_2023-11-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RYFF6TJKCFF75BL2FISASGJUIZO/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R5SSYXQ3PLJOJHICVZRXA4KOBDW/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_11/Targets/Custom Audience/Saslow&Henebrys_Custom_VR_StoreLocations_report/Saslow&Henebrys_Custom_VR_StoreLocations_report_2023-11-28.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_11/Targets/Custom Audience/SalsowHenebrys_Anniversaries_1123.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_11/Targets/Custom Audience/SalsowHenebrys_Birthdays_1123.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_11/Targets/Custom Audience/SaslowandHenebrys-CD-1123-DEMOGRAPHICS-1699465310346.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R5PVHO6GXIYCNAJ3PMA67SQEKE2/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZP7QEFOCNJ2VBZXM62RT22BHGP/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_11/Targets/Custom Audience - OTT/Saslow&Henebrys_Custom_VR_StoreLocations_report/Saslow&Henebrys_Custom_VR_StoreLocations_report_2023-11-28.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_11/Targets/Custom Audience - OTT/SalsowHenebrys_Anniversaries_1123.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_11/Targets/Custom Audience - OTT/SalsowHenebrys_Birthdays_1123.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_11/Targets/Custom Audience - OTT/SaslowandHenebrys-CD-1123-DEMOGRAPHICS-1699465310346.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R6D6VJ7OHC4LBFJYTIU3O4RH325/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R7TV6LRDYS7FNA34T47GUVIYBLD/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_12/Final/Saslow & Henebry''s Jewelry Stores_Standard_2023_12_audit.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_12/Final/Saslow__Henebrys_Jewelry_Stores_Standard_2023_12.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_12/Final/Saslows December Competitor Analysis.xlsx
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R6UFYC4ON7K7JHYIOTAKVYLF6IZ/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_12/Sales/DecemberSales.CSV
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R7FS2FJHKDBQRGLUH3JAJZFYJQO/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZ6B7LIPPFHYNE3R6VIHP5QXVKP/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R7OERBXDHV7K5DIXUPLIN765TAV/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_12/Targets/Competitors/Saslow&Henebrys_VR_report/Saslow&Henebrys_VR_report_2023-12-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R6T4WSRFJEPFVDKXK5QPVHPAMNU/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_12/Targets/Competitors/SaslowHenbreys_VR_FarrarJewelers_1Month_report/SaslowHenbreys_VR_FarrarJewelers_1Month_report_2023-12-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R3K74RAKPA5AZF3S2KWQGAFH4FF/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R6UCADLJK4PPFAIKW3V33CEX4GX/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_12/Targets/Competitors - OTT/Saslow&Henebrys_VR_report/Saslow&Henebrys_VR_report_2023-12-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R4KSZ3KXYYNHFCLQQ57V2RK4A6E/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_12/Targets/Competitors - OTT/SaslowHenbreys_VR_FarrarJewelers_1Month_report/SaslowHenbreys_VR_FarrarJewelers_1Month_report_2023-12-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZQF334LSXXTJDI4NF7BT3H5HZ5/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R2ICWPTYJTIXVFYRAGR7TV4HBJI/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_12/Targets/Custom Audience/Saslow&Henebrys_Custom_VR_StoreLocations_report/Saslow&Henebrys_Custom_VR_StoreLocations_report_2023-12-28.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_12/Targets/Custom Audience/SalsowHenebrys_Anniversary_1223.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_12/Targets/Custom Audience/SaslowandHenebrys-CD-1223-DEMOGRAPHICS-1702416214217.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_12/Targets/Custom Audience/SaslowHenebrys_Birthdays_1223.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZTYECGFMFGXREYBBBK7EDS6CKQ/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R7DUJLYPYO35BB32GOA3FKRAGRI/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_12/Targets/Custom Audience - OTT/Saslow&Henebrys_Custom_VR_StoreLocations_report/Saslow&Henebrys_Custom_VR_StoreLocations_report_2023-12-28.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_12/Targets/Custom Audience - OTT/SalsowHenebrys_Anniversary_1223.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_12/Targets/Custom Audience - OTT/SaslowandHenebrys-CD-1223-DEMOGRAPHICS-1702416214217.csv
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2023_12/Targets/Custom Audience - OTT/SaslowHenebrys_Birthdays_1223.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R7QJ2CFYMWWVRFZDLDP3MUMK24U/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R7E7635SV7SB5HJKEPM45R5JQQ5/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2024_01/Final/Saslow & Henebry''s Jewelry Stores_Standard_2024_01_audit.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2024_01/Final/Saslow__Henebrys_Jewelry_Stores_Standard_2024_01.xlsx
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RYZYLZ4WLGAWVFZMMOYTQ6A5SDB/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2024_01/Sales/JanuarySalesFF.CSV
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RY2YWAEJ5OKQBGY57W3R23ITVHM/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R3EETULO3ZLJBEYMR5NZRXXTZ32/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R4UZQRX3JQRLBB3TUJX52SEIHTW/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2024_01/Targets/Competitors/Saslow&Henebrys_VR_report/Saslow&Henebrys_VR_report_2024-01-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R4MQAIPM2B4NJCLOBN67OXNDBTU/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2024_01/Targets/Competitors/SaslowHenbreys_VR_FarrarJewelers_1Month_report/SaslowHenbreys_VR_FarrarJewelers_1Month_report_2024-01-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZJKFHQVF4JJ5ALZIIRKPR2H67P/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R6I4KKH4CR74RBYLJFX4XBG5VWN/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2024_01/Targets/Competitors - OTT/Saslow&Henebrys_VR_report/Saslow&Henebrys_VR_report_2024-01-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R7G34FEJCZ4TNALLDK5SXHQB5UL/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2024_01/Targets/Competitors - OTT/SaslowHenbreys_VR_FarrarJewelers_1Month_report/SaslowHenbreys_VR_FarrarJewelers_1Month_report_2024-01-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R3MBMSXJSI35ZDLYF2EJUQMFYGB/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RYWMOPDOIWOWRHZXALVPDHTH3FQ/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2024_01/Targets/Custom Audience/Saslow&Henebrys_Custom_VR_StoreLocations_report/Saslow&Henebrys_Custom_VR_StoreLocations_report_2024-01-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RYMXZ6TCHCBCRFK3WNZGYBKLKFJ/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R4ACJHEW56W4BFK64G76H3O4RN6/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2024_01/Targets/Custom Audience - OTT/Saslow&Henebrys_Custom_VR_StoreLocations_report/Saslow&Henebrys_Custom_VR_StoreLocations_report_2024-01-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R42VNKIR6OCKVFYYB5WKGJTTI3H/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R2YM7OFOFE6XJCIS62AAEAB6MP5/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2024_02/Final/Saslow & Henebry''s Jewelry Stores_Standard_2024_02_audit.xlsx
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2024_02/Final/Saslow__Henebrys_Jewelry_Stores_Standard_2024_02.xlsx
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R7CSCAMQCHBJVG2QRSODRL7ILDI/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2024_02/Sales/FebruarySales.CSV
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R7RFOX5MWYHGZCKQVEW37LU4CCW/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R4W6J3DKWSB55BJAIFW6ES6GRS7/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R2ANTMOHTWUFBH2N67K2YPAV44O/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2024_02/Targets/Competitors/Saslow&Henebrys_VR_report/Saslow&Henebrys_VR_report_2024-02-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R32IHJYIKKW4VFJUOKVBTSMD4N2/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZTFSWRS62RVZGZGF32A5RBLZHQ/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/Standard/2024_02/Targets/Competitors - OTT/Saslow&Henebrys_VR_report/Saslow&Henebrys_VR_report_2024-02-28.csv
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R3RFOGTCSSQMVGJN3RGCB4OQDBY/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZGO7TXDQKARRBLZICES23SJM65/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R2PNZA6PRJHCJCIJQJMSKUDVHVU/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R5UZT3X54IUTZBIFT7I7SMFETG3/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RYSVKZRCWQ3WBFYP6NGTMBXVRXH/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R3XKAWGV743FVHL3EQH46OIJIJ5/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RYVN4XKE6NH75CLHXQBROVLQXYS/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R773CYCMPIFDBCLZ2DZJW7JXKE5/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R3R22GWQXN2PJFIKB43DCRF5TWW/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R6JGTRKNT25TJFKQBFEXLZEI6XA/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZM6AWKZSDDNNEJQLAMR64XSJF4/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R7MIWOJ2TKD55GZ5QFFCEULSMPY/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R4T3FOAY6Z7RVAJQ47H7VD4FWLP/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZMSKYORJATFNFI4ABZAOZHRXAT/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RY562FZMSD3IFBJK55ZWMKW3U4V/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R2RRE5UNNBCJVD3GNQIJ6UOPZN3/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R2D7W6BGGA5NJH3A4N6BXO6KWWA/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZ5WMHWHNF6XJCLPXSFYPNYRCIC/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RYYT7SO3EIMDJBJ2JKUPF2MCYJX/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R5PZN52DWNSNZBJ3Z2MDN3SV5QN/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R7WGFT2GUX7BRC3ILE4G22JVFOX/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R47PQDHY5EPHVA3PN2COXUKCF4F/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R66SQ3BHCUAWVCZSG3WKMADCP4D/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R4BTR4QM7GFFNDYRNMHRRBQW2SP/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R5NOHDKPVQHQREJ7YGNRXNIPQZ3/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZTNTSRYR3RVFEI4TRK6FJLUXWY/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZNGAH3XFZ5IBD2I7JNA5LJGGG4/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R5T7QQHXT4XQRA2BZ5MK3P2KIQI/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7RZQXOBE3YIP7ZH2U2O3RH64QDOJ/children
# INFO:__main__:REQUESTING | https://graph.microsoft.com/v1.0/drives/b!BQjd_4H_SE-hirG4TNaEuMHMlw9FCzxGqhsmdxk6dEgemQXUVLKjRJlKzr7bv1iU/items/01KIAY7R5AJQPLA6S64NGIH6US2OAPVAGB/children
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/DecemberAnniversary.CSV
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/DecemberBday.CSV
# INFO:__main__:STARTING Saslow & Henebry's Jewelry Stores/AdOps/SaslowHenebrysFootTrafficCounts.csv
# INFO:__main__:FINISHED | Team: Saslow & Henebry's Jewelry Stores | Channel: AdOps

# %%
# Define the ContainerClient
container_client = ContainerClient.from_connection_string(
    os.environ["COLD_STORAGE"], "teams"
)
for team_name in [
    "Alive Wellness and Fitness",
    "Andersons Warehouse",
    "Appliance Barn by Sleep Center",
    "Big's Furniture",
    "Blue Bell Mattress - Gardner White",
    "C4 Repo Trailer Sales (Hopkins)",
    "Carolina Moving Solutions",
    "Carson Home Furnishings",
    "Carson Newman University",
    "Cheap Sleep",
    "City Furniture",
    "Coastal Urge",
    "Comfy Planets",
    "CrossFit Republic",
    "DD Mattress Co",
    "Divano Furniture",
    "Englander",
    "ESC Mattress Center",
    "Full House Furniture",
    "Furniture 4 Less Outlet",
    "Furniture World LV",
    "Germain Yachts",
    "Great American Home Store",
    "Happy's Home Centers",
    "HOM Furniture",
    "Home Suite Home",
    "Home Zone Furniture",
    "HTF Trailers (Hopkins)",
    "Jack and Jill Adult Superstore",
    "JB Windows",
    "Jenny's Stores",
    "Jonathan Stevens Mattress Co",
    "Joyology",
    "KidStrong",
    "KitchenSearch.com",
    "Kueblers Furniture",
    "Liquid Planet Grille",
    "M&D Trailer Sales (Hopkins)",
    "Mack Mattress",
    "Mattress Clearance Center of NWA",
    "Mattress Clinic",
    "Mattress Hub",
    "Mattress on Demand",
    "Mattress Sleep Centers",
    "Mattress Store (St. George)",
    "MattressLand",
    "Michael Alan",
    "MPG - Designs In Stone",
    "MPG - Merridian Home Furnishings",
    "MPG - World Class Services",
    "MPG Biscuit Belly",
    "MPG Buff City Soap",
    "MPG Carnes Trucking",
    "MPG Cashel Fly",
    "MPG Churchill Downs",
    "MPG Discovery Builders",
    "MPG Downey Trucking",
    "MPG Fasig Tipton",
    "MPG Franklin Brazing",
    "MPG KSculpt",
    "MPG Mark's Feed Store",
    "MPG Merck Animal Health Equine",
    "MPG PDQ Doors",
    "MPG PXG",
    "MPG Ritchie Industries",
    "MPG Sportsmens Alliance",
    "MPG Thorntons",
    "MPG Zoom Room Florida",
    "MyHome Center",
    "Old Westbury",
    "Pantibiotic",
    "Pure Glow",
    "REM Sleep Solutions",
    "Rent-Buy Texas",
    "Revenge Rum",
    "Rosso Furniture",
    "RTB ABP",
    "RTB Burlington Channel",
    "RTB CO Denver",
    "RTB FL Estero",
    "RTB GA Atlanta",
    "RTB TN Memphis",
    "Ryan Testing Team",
    "Saslow & Henebry's Jewelry Stores",
    "Scott & Eric Podcast Team",
    "Snooze - Pueblo West",
    "Sofas 2 Furnishings",
    "Sparks Furniture",
    "St. Margaret's School",
    "Straight Blast Gym",
    "SunMed",
    "SUNY Buffalo",
    "SUNY Fredonia",
    "The American Furniture",
    "The FAM",
    "The Joint - MA",
    "The Joint – Massachusetts",
    "The Joint Detroit",
    "The Joint Weymouth",
    "Tyndall Furniture",
    "Uneeda Shed (Hopkins)",
    "Walker Furniture (LV)",
    "Wright Entertainment Group",
    "38 Special Luxury RV Resort",
]:
    await process_team(client, container_client, team_name)
